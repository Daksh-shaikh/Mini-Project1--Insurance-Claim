# %%
#import libraries

#for manipulation
import pandas as pd
import numpy as np

#for data visualization 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#lets read the dataset
data=pd.read_csv("insurance.csv")
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
# lets check the head of the data 
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
# lets check the shape of the data..
data.shape
# Out:
# (1338, 8)

# %%
# lets check the size of the data..
data.size
# Out:
# 10704

# %%
# lets check the info of the data..
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             1338 non-null   int64
#  1   sex             1338 non-null   int64
#  2   bmi             1338 non-null   float64
#  3   children        1338 non-null   int64
#  4   smoker          1338 non-null   int64
#  5   region          1338 non-null   int64
#  6   charges         1338 non-null   float64
#  7   insuranceclaim  1338 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 83.8 KB

# %%
#lets describe the dataset
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges  insuranceclaim
# count  1338.000000   1338.000000     1338.000000
# mean      1.515695  13270.422265        0.585202
# std       1.104885  12110.011237        0.492871
# min       0.000000   1121.873900        0.000000
# 25%       1.000000   4740.287150        0.000000
# ...

# %%
# Checking value count of gender 
data['sex'].value_counts()
# Out:
# 1    676
# 0    662
# Name: sex, dtype: int64

# %%
# there are 676 male(1) and 662 female(0)
# both are nearly equal

# %%
# lets check null values 

data.isna().sum()
# Out:
# age               0
# sex               0
# bmi               0
# children          0
# smoker            0
# region            0
# charges           0
# insuranceclaim    0
# dtype: int64

# %%
# there is no null values.

# %%
# if there is any null or missing values 

# Fill-NA function is used to replace these missing values with statistical values such as mean, median or mode. 
# NA means not available
# Pandas have function like fill-NA, drop-NA to treat missing values


# when to use mean, mode or median 

# mean - when there is numerical values in our column
# mode - when there is categorical values in our column
# median - when there is more outliers in our column

# %%
# lets check Value count of insurance claim in our dataset

data['insuranceclaim'].value_counts()

# %%
# all the features of data are important on the basis of insurance claim

# %%
# lets check unique values in each column

data.nunique()
# Out:
# age                 47
# sex                  2
# bmi                548
# children             6
# smoker               2
# region               4
# charges           1337
# insuranceclaim       2
# dtype: int64

# %% [markdown]
# # Visualization

# %%
# Lets create count plot for age 
age_counts = data['age'].value_counts()
y='age'
sns.countplot(x= age_counts, palette="Set1")
plt.show()

# %%
# maximum people are of age 28

# %%
# lets create count plot for Sex feature

sns.countplot(x="sex", data=data, hue='sex', dodge = False , palette="Set2")
plt.show()

# %%
# here we can see both genders are nearly in equal numbers

# %%
#Lets create a line plot between age and insurance claim:

sns.lineplot(x='age', y='insuranceclaim', data=data)
plt.title("Line Plot Between Age and insuranceclaim")
plt.show()

# %%
# Lets create bar plot between age and bmi 

plt.bar('age','bmi', width=0.7, color='red', data=data)  
plt.xlabel("age")
plt.ylabel('bmi')
plt.title("age vs bmi")
plt.show()

# %%
children_counts = data['children'].value_counts()

# Plot a pie chart of the 'children' column
plt.pie(children_counts, labels=children_counts.index, autopct='%1.f%%', startangle=90, pctdistance=1.1, labeldistance=0.7)
plt.axis('equal')
plt.title('Number of Children')
plt.show()

# %%
# line plot for smoker vs charges

#line plot:

sns.lineplot(x='smoker', y='charges', data=data)
plt.show()

# %%
# by the above graph smokers have to pay more charges then non-smoker.

# %%
# lets create count plot for region feature

sns.countplot(x="region", data=data, hue='region', dodge = False , palette="Set2")
plt.show()

# %%
# lets create pairplot  ----> shows all possible graphs

sns.pairplot(data=data)
plt.show()

# %%
# value cout of smokers

data['smoker'].value_counts()
# Out:
# 0    1064
# 1     274
# Name: smoker, dtype: int64

# %%
#lets describe the dataset
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges  insuranceclaim
# count  1338.000000   1338.000000     1338.000000
# mean      1.515695  13270.422265        0.585202
# std       1.104885  12110.011237        0.492871
# min       0.000000   1121.873900        0.000000
# 25%       1.000000   4740.287150        0.000000
# ...

# %%
#insights of dataset

# dataset contain only 18 and above 18 age people
# 75% people are >50 age 
# male and females are nearly equal in numbers 
# mostly people have 2 childrens 
# Maximum childrens are 5
# max bmi is 53 which may be considered severely or morbidly obese 
# mostly people are not smoker 
# min charges is 1121 and maximum 63770
# 75% charges are 16639
# smokers have to pay more charges then non-smokers

# %% [markdown]
# # Lets work on Outliers

# %%
# lets check skewness, hist plot and box plot of each feature

# %%
# For Age feature
print("Age: ")
print("Skewness : ", round(data['age'].skew(), 3))
plt.figure(figsize=(13,5))
plt.subplot(1, 2, 1)
sns.histplot(data=data['age'], kde=True)
plt.subplot(1,2,2)
plt.boxplot(x=data['age'], vert=False)
plt.show()
# Out:
# Age:
# Skewness :  0.056

# %%
# For Sex feature
print("Sex: ")
print("Skewness : ", round(data['sex'].skew(), 3))
plt.figure(figsize=(13,5))
plt.subplot(1, 2, 1)
sns.histplot(data=data['sex'], kde=True)
plt.subplot(1,2,2)
plt.boxplot(x=data['sex'], vert=False)
plt.show()
# Out:
# Sex:
# Skewness :  -0.021

# %%
# For BMI feature
print("BMI: ")
print("Skewness : ", round(data['bmi'].skew(), 3))
plt.figure(figsize=(13,5))
plt.subplot(1, 2, 1)
sns.histplot(data=data['bmi'], kde=True)
plt.subplot(1,2,2)
plt.boxplot(x=data['bmi'], vert=False)
plt.show()
# Out:
# BMI:
# Skewness :  0.284

# %%
# For Smoker feature
print("smoker: ")
print("Skewness : ", round(data['smoker'].skew(), 3))
plt.figure(figsize=(13,5))
plt.subplot(1, 2, 1)
sns.histplot(data=data['smoker'], kde=True)
plt.subplot(1,2,2)
plt.boxplot(x=data['smoker'], vert=False)
plt.show()
# Out:
# smoker:
# Skewness :  1.465

# %%
# For region feature

print("region: ")
print("Skewness : ", round(data['region'].skew(), 3))
plt.figure(figsize=(13,5))
plt.subplot(1, 2, 1)
sns.histplot(data=data['region'], kde=True)
plt.subplot(1,2,2)
plt.boxplot(x=data['region'], vert=False)
plt.show()
# Out:
# region:
# Skewness :  -0.038

# %%
# For charges feature 
print("charges: ")
print("Skewness : ", round(data['charges'].skew(), 3))
plt.figure(figsize=(13,5))
plt.subplot(1, 2, 1)
sns.histplot(data=data['charges'], kde=True)
plt.subplot(1,2,2)
plt.boxplot(x=data['charges'], vert=False)
plt.show()
# Out:
# charges:
# Skewness :  1.516

# %%
# bmi and charges can be more or less so we are not treating them as outliers

# %%
# Skewness of complete data
S= round(data.skew(), 3)
S = sum(S)/len(S)
print("Average of total Skewness : ", S)
# Out:
# Average of total Skewness :  0.48175

# %% [markdown]
# # Correlation

# %%
# Lets check correlation of data

data.corr()
# Out:
#                      age       sex       bmi  children    smoker    region  \
# age             1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127
# sex            -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588
# bmi             0.109272  0.046371  1.000000  0.012759  0.003750  0.157566
# children        0.042469  0.017163  0.012759  1.000000  0.007673  0.016569
# smoker         -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181
# region          0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000
# charges         0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208
# insuranceclaim  0.113723  0.031565  0.384198 -0.409526  0.333261  0.020891
#
#                  charges  insuranceclaim
# age             0.299008        0.113723
# sex             0.057292        0.031565
# bmi             0.198341        0.384198
# children        0.067998       -0.409526
# smoker          0.787251        0.333261
# region         -0.006208        0.020891
# ...

# %%
# Heatmap of data 
sns.heatmap(data=data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#data has correlation not more than 0.79 that means our dataset feature has no correlation.

# %%
# Divide data into dependent and independent features 

X=data.drop(['insuranceclaim'], axis=1).values  # independent feature
y=data['insuranceclaim'].values                 # dependent feature (label)

# %% [markdown]
# # Scaling by Standardization

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
X=sd.fit_transform(X)

# %%
# Lets make training and testing model 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
print("X_train shape : ", X_train.shape)
print("X_test shape: ", X_test.shape)
print("y_train shape: ", y_train.shape)
print("y_test shape : ", y_test.shape)
# Out:
# X_train shape :  (936, 7)
# X_test shape:  (402, 7)
# y_train shape:  (936,)
# y_test shape :  (402,)

# %% [markdown]
# # Model

# %%
# Model 
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=5)

#fitting
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
#Predicting 
from sklearn import metrics  # to find accuracy

y_pred = clf.predict(X_test)
acc= metrics.accuracy_score(y_test, y_pred)
print("Accuracy : ", acc*100)
# Out:
# Accuracy :  88.30845771144278

# %%
# Lets check accuracy for training data

# %%
#Predicting 

y_training = clf.predict(X_train)
acc= metrics.accuracy_score(y_train, y_training)
print("Accuracy : ", acc*100)
# Out:
# Accuracy :  91.23931623931624

# %%
# lets evaluate the model performance 

from sklearn.metrics import confusion_matrix

#Lets print the confusion metrix first

plt.rcParams['figure.figsize'] = (10,10)
cm=confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Wistia')
plt.title("Confusion matrix for Decision Tree", fontsize=15)
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# calculate the confusion matrix
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

# print the confusion matrix
print("Confusion Matrix:")
print("True Negative:", tn, "False Positive:", fp)
print("False Negative:", fn, "True Positive:", tp)
# Out:
# Confusion Matrix:
# True Negative: 154 False Positive: 26
# False Negative: 21 True Positive: 201

# %%
# Lets print the classifiction report also 
from sklearn.metrics import classification_report

cr= classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       180
#            1       0.89      0.91      0.90       222
#
#     accuracy                           0.88       402
#    macro avg       0.88      0.88      0.88       402
# weighted avg       0.88      0.88      0.88       402

# %%
# As all the values of precision recall and f1-score is nearer to 1
# We can say our model gives good precision, recall and f1-score
# High precision indicates that the model is making fewer false positive predicions 
# While high recall indicates that the model is making fewer false negative predictions

# %%
# Lets check the Head of the Dataset 

data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
# Lets check how model predicts the result 


prediction= clf.predict((np.array([[32, 1, 27, 0, 0, 1, 3800]])))

print("The suggested insurance claim for given condition is : ", prediction)
# Out:
# The suggested insurance claim for given condition is :  [1]

# %%
prediction= clf.predict((np.array([[28, 1, 33, 3, 0, 2, 3800]])))

print("The suggested insurance claim for given condition is : ", prediction)
# Out:
# The suggested insurance claim for given condition is :  [0]

# %%
# By testing our model for unknown data we can see our model works properly.

# %%
# Note

# We applied many models to the data, but decision tree gave the best accuracy among all of them. 
# Decision Tree Classifier - It gives 88% on testing and 91% on training data
# Logistic Regression - It gives 87% accuracy on testing and 88% on training data 
# SVC - It gives 87% accuracy 
# Naive Bayes - It gives 76% Accuracy
